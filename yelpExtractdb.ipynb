# %%
import requests
import json
import pandas as pd
# Import API key
from yelp_keys import api_key
import pymongo

# %%
yelpAPI = 'https://api.yelp.com/v3/businesses/search'
header = {'Authorization':'bearer %s' % api_key}
parameters = {'term':'restaurants',
             'limit':50,
             'longitude': 40.7150,
             'longitude': -73.9843,
             'radius':1000,
             'categories' : 'All',
             'location': 'New York City',
             'is_closed': False}

# send a request
response = requests.get(url = yelpAPI, params = parameters, headers = header)

# %%
response
restaurant_data = response.json()
restaurant_data
# Out:
# {'businesses': [{'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 2051,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 323.20506308227306},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxY50B6ntFYQa8COuI1Fog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 525,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 671.0784555500173},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TAog5s7slOJ0778OGRzuWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 647,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 392.6441573431464},
#   {'id': 'MGd6HFEq1ALD58XWNviSXw',
#    'alias': 'time-out-market-new-york-brooklyn',
#    'name': 'Time Out Market New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TmhwMz3q6IdmVVC8ZgZc8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/time-out-market-new-york-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 108,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7037211399782,
#     'longitude': -73.9918105285751},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19178104855',
#    'display_phone': '(917) 810-4855',
#    'distance': 283.7853104247956},
#   {'id': '97q5nUQTuBo_h00XCxna2A',
#    'alias': 'tasty-hand-pulled-noodles-new-york',
#    'name': 'Tasty Hand-Pulled Noodles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Hr13sbfbSCO0xqVF8W701Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-hand-pulled-noodles-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1544,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142, 'longitude': -73.99787},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1 Doyers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Doyers St', 'New York, NY 10013']},
#    'phone': '+12127911817',
#    'display_phone': '(212) 791-1817',
#    'distance': 1020.1959880192533},
#   {'id': '_N92SH1Zi-Hbxn_bNHFz0Q',
#    'alias': 'noodle-pudding-brooklyn',
#    'name': 'Noodle Pudding',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o5ygMLdH6f5XVONTb3msMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodle-pudding-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 550,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69979, 'longitude': -73.99203},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '38 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17186253737',
#    'display_phone': '(718) 625-3737',
#    'distance': 655.5435192103048},
#   {'id': '3UdlrH-tuVM0vy3ySh7bUw',
#    'alias': 'jacobs-pickles-time-out-market-brooklyn-2',
#    'name': "Jacob's Pickles Time Out Market",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ijmzO6wtWfD7t48YPLT1eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacobs-pickles-time-out-market-brooklyn-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 9,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70362, 'longitude': -73.99165},
#    'transactions': [],
#    'location': {'address1': '55 Water St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 287.93938729287737},
#   {'id': '4XX-zF8h5Lvrr22_tqU6-Q',
#    'alias': 'the-river-café-brooklyn-3',
#    'name': 'The River Café',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rxg5eDnRtIm73UEuNa3NHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1073,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70318, 'longitude': -73.9946499},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225200',
#    'display_phone': '(718) 522-5200',
#    'distance': 254.64706598521875},
#   {'id': 'qOomR3AwClOGpV1HdqOTFg',
#    'alias': 'les-enfants-de-boheme-new-york',
#    'name': 'Les Enfants de Boheme',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I1V4kucJO69x8L8UhDwiiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 213,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7136187, 'longitude': -73.9888503},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '177 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Henry St', 'New York, NY 10002']},
#    'phone': '+16464764843',
#    'display_phone': '(646) 476-4843',
#    'distance': 1026.2110364656392},
#   {'id': 'dzlhiEg7nE49iReUC10w_A',
#    'alias': 'jack-the-horse-tavern-brooklyn',
#    'name': 'Jack the Horse Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bBcZj7gSfZFZgp4gUY9uCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jack-the-horse-tavern-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 381,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.699973, 'longitude': -73.993781},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '66 Hicks St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Hicks St', 'Brooklyn, NY 11201']},
#    'phone': '+17188525084',
#    'display_phone': '(718) 852-5084',
#    'distance': 602.6367999119216},
#   {'id': '-Gc5sTFxoXM3Tiv_dkSJZg',
#    'alias': 'cecconis-dumbo-brooklyn',
#    'name': "Cecconi's Dumbo",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IBLvIwCEjW-CiJUc6fo5Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cecconis-dumbo-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 562,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7033063330116,
#     'longitude': -73.9916549604523},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17186503900',
#    'display_phone': '(718) 650-3900',
#    'distance': 325.5822990331506},
#   {'id': '4aF0F8w7yXX9o5_QFky_ig',
#    'alias': 'celestine-brooklyn',
#    'name': 'Celestine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J5HuHor_cmVEG6HhQtFeDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celestine-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 192,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704676, 'longitude': -73.987975},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 John St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225356',
#    'display_phone': '(718) 522-5356',
#    'distance': 539.4069533813018},
#   {'id': 'XipQLDbyTl5tsLlyzAWzug',
#    'alias': 'jajaja-new-york',
#    'name': 'Jajaja',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QaIhCEp1FpU3a2teWQh6mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 755,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141530317142,
#     'longitude': -73.9904247969389},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E Broadway', 'New York, NY 10002']},
#    'phone': '+16468835453',
#    'display_phone': '(646) 883-5453',
#    'distance': 1021.7274074140097},
#   {'id': 'R26zweQ8-xoZS7iHkXQOvw',
#    'alias': 'shanghai-21-new-york-2',
#    'name': 'Shanghai 21',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O3Md1QIqHqd1WUDBAuo7_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shanghai-21-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1571,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7144199, 'longitude': -73.99889},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Mott St', 'New York, NY 10013']},
#    'phone': '+12127666311',
#    'display_phone': '(212) 766-6311',
#    'distance': 1073.9510052935152},
#   {'id': 'RrNe_0PReWHXAnjTEXBikQ',
#    'alias': 'lukes-lobster-brooklyn-bridge-park-brooklyn-2',
#    'name': "Luke's Lobster Brooklyn Bridge Park",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hmq1cKYVpG8SkM0nIN2l9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-brooklyn-bridge-park-brooklyn-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 299,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70359, 'longitude': -73.99411},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19178827516',
#    'display_phone': '(917) 882-7516',
#    'distance': 219.32290848983465},
#   {'id': 'bnDfFdiCcPzhuNWUJORvLQ',
#    'alias': 'noodle-village-new-york',
#    'name': 'Noodle Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TwBJ_7nfanDH2CNQ-NQxQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodle-village-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1010,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714167, 'longitude': -73.998803},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '13 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 Mott St', 'New York, NY 10013']},
#    'phone': '+12122330788',
#    'display_phone': '(212) 233-0788',
#    'distance': 1041.687819907976},
#   {'id': 'xeC9vn3dxVVzAMR_aFwfXg',
#    'alias': 'il-brigante-new-york',
#    'name': 'IL Brigante',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qk5GDAERuUt9cd25PZhQTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-brigante-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 367,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.707492, 'longitude': -74.002571},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '214 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Front St', 'New York, NY 10038']},
#    'phone': '+12122850222',
#    'display_phone': '(212) 285-0222',
#    'distance': 738.248263617683},
#   {'id': 'toxwdOCz37bX5dJ_O1h2Ew',
#    'alias': 'sugarcane-raw-bar-grill-brooklyn-7',
#    'name': 'Sugarcane Raw Bar Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8L4Nc2iGlPIaYQ8rc_ZD3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugarcane-raw-bar-grill-brooklyn-7?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 491,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.703799, 'longitude': -73.992343},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '55 Water St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17184739555',
#    'display_phone': '(718) 473-9555',
#    'distance': 246.00446691411784},
#   {'id': '5Fz1WlY3lxy8gJFs8s_1Dw',
#    'alias': 'the-binc-brooklyn',
#    'name': 'The Binc',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RK3WuC6Nowcz2r2UeEO79Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-binc-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 68,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6992682, 'longitude': -73.9923109},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '60 Henry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17186241444',
#    'display_phone': '(718) 624-1444',
#    'distance': 715.0007787095552},
#   {'id': 'Pe4cQ65ZJ9qS8JQZVkJz4g',
#    'alias': 'shabushabu-mayumon-new-york',
#    'name': 'shabushabu Mayumon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8M0o0ssFjo9EIadjiX2Byw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shabushabu-mayumon-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 6,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71434, 'longitude': -73.99205},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '115 Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Division St', 'New York, NY 10002']},
#    'phone': '+16464767717',
#    'display_phone': '(646) 476-7717',
#    'distance': 995.7191551606902},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'alias': 'almar-brooklyn-2',
#    'name': 'AlMar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TTzeaitXeXWX0MBzLun3xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 406,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702662, 'longitude': -73.989177},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188555288',
#    'display_phone': '(718) 855-5288',
#    'distance': 530.8013177444826},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-pizzeria-brooklyn-4',
#    'name': "Grimaldi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNKqW31PTvtSw6-Lbc1mtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 4541,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70257, 'longitude': -73.99323},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 327.45636528596714},
#   {'id': '0GftSP2dRwEzujkv2VKIgA',
#    'alias': 'wok-wok-new-york',
#    'name': 'Wok Wok',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6oKmNAJiYRln7GNXhf2lsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wok-wok-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 846,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71406, 'longitude': -73.99883},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Mott St', 'New York, NY 10013']},
#    'phone': '+19173883627',
#    'display_phone': '(917) 388-3627',
#    'distance': 1033.5545870381047},
#   {'id': 'j-a8HUcsBJXHV2IfF786jw',
#    'alias': 'kogane-ramen-brooklyn-heights',
#    'name': 'Kogane Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nCavIzqgP6sGG5Sitq_MCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kogane-ramen-brooklyn-heights?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 303,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.698608, 'longitude': -73.992675},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '76 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn Heights',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76 Henry St', 'Brooklyn Heights, NY 11201']},
#    'phone': '+17188752828',
#    'display_phone': '(718) 875-2828',
#    'distance': 770.8437319673892},
#   {'id': 'q11TljTQd33XCWlVoPyRqg',
#    'alias': 'the-osprey-brooklyn',
#    'name': 'The Osprey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kwlyMi4cASfqcvEl0Mmb_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-osprey-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 159,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702241, 'longitude': -73.995539},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '60 Furman St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+13476962505',
#    'display_phone': '(347) 696-2505',
#    'distance': 367.7475436977597},
#   {'id': 'CqtT8rPaSmrRClUBbqsCFA',
#    'alias': 'seamores-brooklyn',
#    'name': "Seamore's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QBPv2XXH3Inp60QNMypPdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seamores-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 89,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7032, 'longitude': -73.99145},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '66 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17186636550',
#    'display_phone': '(718) 663-6550',
#    'distance': 361.28143291784545},
#   {'id': 'r2JVKalbucGf2nryywuL2w',
#    'alias': 'kopitiam-new-york',
#    'name': 'Kopitiam',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NGu52ghjQIm0XPW0DnTYiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kopitiam-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 519,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'singaporean', 'title': 'Singaporean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71387, 'longitude': -73.99091},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '151 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 E Broadway', 'New York, NY 10002']},
#    'phone': '+16466093785',
#    'display_phone': '(646) 609-3785',
#    'distance': 974.5409367264409},
#   {'id': 'WFyGR8sW10AzbAoQ4T7Ung',
#    'alias': 'the-paris-cafe-new-york',
#    'name': 'The Paris Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fo01DK3O0PWgcfcf4dN10w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-paris-cafe-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 302,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70732, 'longitude': -74.00159},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '119 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 South St', 'New York, NY 10038']},
#    'phone': '+12122409797',
#    'display_phone': '(212) 240-9797',
#    'distance': 645.5252755847498},
#   {'id': '9-vKFnUby_6-pR6UJxjzMw',
#    'alias': 'sun-hing-lung-co-new-york-3',
#    'name': 'Sun Hing Lung Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/l07KZELAnbW1l7YNP_L2Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-hing-lung-co-new-york-3?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 176,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71275, 'longitude': -73.99508},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '58 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 Henry St', 'New York, NY 10002']},
#    'phone': '+12129627032',
#    'display_phone': '(212) 962-7032',
#    'distance': 813.2959782363168},
#   {'id': 'QDApjjZAPxFvvbll86NMTA',
#    'alias': 'hak-box-new-york-2',
#    'name': 'Hak Box',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s3pzzSOtlh3Wbojf1mRQOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hak-box-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 28,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.713982, 'longitude': -73.9942284},
#    'transactions': [],
#    'location': {'address1': '88 E Broadway',
#     'address2': 'Unit 106',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 E Broadway', 'Unit 106', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 949.300827892563},
#   {'id': '56qlj1cYlqNzmG0xllGg-w',
#    'alias': 'westville-dumbo-brooklyn',
#    'name': 'Westville Dumbo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y9agcxhbRPYMNzsk4b9Peg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westville-dumbo-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 242,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7017969340086,
#     'longitude': -73.9896315336227},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '81 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Washington St', 'Brooklyn, NY 11201']},
#    'phone': '+17186185699',
#    'display_phone': '(718) 618-5699',
#    'distance': 559.7246737077468},
#   {'id': 'kNOr6_g6QfBHdhf89j3g5w',
#    'alias': 'taiwan-pork-chop-house-new-york',
#    'name': 'Taiwan Pork Chop House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KrvKvI_lYJ5FBcHFeXKYWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taiwan-pork-chop-house-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 415,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71424, 'longitude': -73.99799},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3 Doyers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Doyers St', 'New York, NY 10013']},
#    'phone': '+12127917007',
#    'display_phone': '(212) 791-7007',
#    'distance': 1028.3299851000538},
#   {'id': 'Fuk7jDI2XAcvHxqau5rKWA',
#    'alias': 'acqua-restaurant-nyc-new-york',
#    'name': 'Acqua Restaurant NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lAKKxeZrcPVODADlao1ajQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/acqua-restaurant-nyc-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 355,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7082567, 'longitude': -74.001797},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21 Peck Slip, Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Peck Slip, Water St', 'New York, NY 10038']},
#    'phone': '+12123494433',
#    'display_phone': '(212) 349-4433',
#    'distance': 705.5667555515262},
#   {'id': 'VaL9GaBR_GR-q9d1VzJF3g',
#    'alias': 'suteishi-new-york',
#    'name': 'Suteishi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YEpRTAWG3xlGrLV3sFFohQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suteishi-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 468,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70788, 'longitude': -74.00194},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '24 Peck Slip',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Peck Slip', 'New York, NY 10038']},
#    'phone': '+12127662344',
#    'display_phone': '(212) 766-2344',
#    'distance': 698.6830054511408},
#   {'id': 'kDJbzzmCEjFbyDQ-lSygvw',
#    'alias': 'fresh-salt-new-york',
#    'name': 'Fresh Salt',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UL2XnK_9pl0-kxHjUpjweg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-salt-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 386,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70707, 'longitude': -74.00244},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146 Beekman St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Beekman St', 'New York, NY 10038']},
#    'phone': '+12129620053',
#    'display_phone': '(212) 962-0053',
#    'distance': 710.677389267444},
#   {'id': '-2UtjTxrt1Xzd-HPsLJ7mA',
#    'alias': 'butler-brooklyn-2',
#    'name': 'Butler',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U4lXZCW47KCPbh30XMrt1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 63,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7032670673495,
#     'longitude': -73.9922419276899},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '40 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Water St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 299.48141504845114},
#   {'id': '4zBGXDXg9DzK0IROwCUeFg',
#    'alias': 'cowgirl-seahorse-new-york-2',
#    'name': 'Cowgirl Seahorse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mRCV94yIU3zkKiL6FPR6Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cowgirl-seahorse-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 557,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7081358, 'longitude': -74.0004532},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '259 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 Front St', 'New York, NY 10038']},
#    'phone': '+12126087873',
#    'display_phone': '(212) 608-7873',
#    'distance': 599.2822281843487},
#   {'id': 'b42PcC1nCP602fiXF0a9Xg',
#    'alias': 'barbalu-restaurant-new-york',
#    'name': 'Barbalu Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-i2phwCUNAqTKm5WGuGzHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbalu-restaurant-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 268,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7074747, 'longitude': -74.0020404},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '225-227 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225-227 Front St', 'New York, NY 10038']},
#    'phone': '+16469186565',
#    'display_phone': '(646) 918-6565',
#    'distance': 690.9347453308609},
#   {'id': 'I4LSdJd2Z8M6VNLhbX3aLA',
#    'alias': 'superfine-brooklyn',
#    'name': 'Superfine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DRJnzqoFIK3VtL8Gk1MKBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/superfine-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 441,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702236, 'longitude': -73.987426},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '126 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17182439005',
#    'display_phone': '(718) 243-9005',
#    'distance': 684.5691418649358},
#   {'id': 'z3TwiFWdJUvY9tW8QMEseQ',
#    'alias': 'taco-dumbo-brooklyn',
#    'name': 'Taco Dumbo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/25eTHDdSHG5vAVkKeWazWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-dumbo-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 161,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.700601, 'longitude': -73.988467},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '56 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56 Prospect St', 'Brooklyn, NY 11201']},
#    'phone': '+13472020306',
#    'display_phone': '(347) 202-0306',
#    'distance': 728.9122627706757},
#   {'id': 'xhuDOqY9G5mPuSqBnMCaYw',
#    'alias': 'henrys-end-brooklyn-4',
#    'name': "Henry's End",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h_JcEVjz8dGX9qIZ63R1QQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henrys-end-brooklyn-4?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 344,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.698689, 'longitude': -73.99256},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '72 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17188341776',
#    'display_phone': '(718) 834-1776',
#    'distance': 765.293456182874},
#   {'id': 'Rv4NgRl-wkMNPNdqXNSGBg',
#    'alias': 'shake-shack-brooklyn-12',
#    'name': 'Shake Shack',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pNQG8A5yWy4NuN9aIcIo8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shake-shack-brooklyn-12?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 331,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7030151, 'longitude': -73.9939538},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+13474352676',
#    'display_phone': '(347) 435-2676',
#    'distance': 271.68785695010257},
#   {'id': 'zubN8Ve-RyoljRZV4NRxEQ',
#    'alias': 'wo-hop-new-york',
#    'name': 'Wo Hop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S8GzetIlPutiaN16AG8NHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wo-hop-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1359,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7142239034582,
#     'longitude': -73.9988691693115},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '17 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Mott St', 'New York, NY 10013']},
#    'phone': '+12129628617',
#    'display_phone': '(212) 962-8617',
#    'distance': 1049.617979893339},
#   {'id': 'tguMh2GgOcU9fu6WN3dqpw',
#    'alias': 'the-original-buddha-bodai-kosher-vegetarian-restaurant-new-york-3',
#    'name': 'The Original Buddha Bodai - Kosher Vegetarian Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rnOwCozv8fXOmR-R_8Jv2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-original-buddha-bodai-kosher-vegetarian-restaurant-new-york-3?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 942,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7138543, 'longitude': -73.9989484},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Mott St', 'New York, NY 10013']},
#    'phone': '+12125668388',
#    'display_phone': '(212) 566-8388',
#    'distance': 1014.0737683057544},
#   {'id': 'aac8M8uK8XUDBNUR_SyZdw',
#    'alias': 'the-bao-shoppe-new-york-2',
#    'name': 'The Bao Shoppe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t5QrNNR-1nWcFeg4HVSWyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bao-shoppe-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 189,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7143451, 'longitude': -73.9905184},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '34 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34 Canal St', 'New York, NY 10002']},
#    'phone': '+16467564181',
#    'display_phone': '(646) 756-4181',
#    'distance': 1036.4731519500822},
#   {'id': '3hRE9hN7Yp9AHJD8ahAVDQ',
#    'alias': 'markjoseph-steakhouse-new-york-2',
#    'name': 'MarkJoseph Steakhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fdhOmLNwPHrDbLaviDysjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/markjoseph-steakhouse-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 390,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70837, 'longitude': -74.00152},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '261 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Water St', 'New York, NY 10038']},
#    'phone': '+12122770020',
#    'display_phone': '(212) 277-0020',
#    'distance': 687.0005442107365},
#   {'id': 'LOeDR4X-YRToeo3hy_plew',
#    'alias': 'the-fulton-new-york-2',
#    'name': 'The Fulton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GFOoINd9z9q3CDQ3npDXkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fulton-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 77,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7053694327276,
#     'longitude': -74.0010633899353},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '89 South St',
#     'address2': 'Pier 17',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 South St', 'Pier 17', 'New York, NY 10038']},
#    'phone': '+12128381200',
#    'display_phone': '(212) 838-1200',
#    'distance': 570.7452805978547},
#   {'id': 'dUfTg2SJ2nH48J8VhAuZ_A',
#    'alias': 'my-noodle-station-new-york-5',
#    'name': 'My Noodle Station',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DNRq2DqipFR2844p0qWmQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-noodle-station-new-york-5?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 37,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714047, 'longitude': -73.992304},
#    'transactions': ['pickup'],
#    'location': {'address1': '19 Eldridge St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Eldridge St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 971.0968048783278},
#   {'id': 'WoAvunLY0_L0ix8Vgit8gQ',
#    'alias': 'the-tuck-room-new-york',
#    'name': 'The Tuck Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ESYMIZ23fr3fekULC8r1Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tuck-room-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 243,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70654, 'longitude': -74.00325},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Fulton St', 'New York, NY 10038']},
#    'phone': '+12127768273',
#    'display_phone': '(212) 776-8273',
#    'distance': 758.1753268165406},
#   {'id': 'ynB8T3htx8s5V0YV8gVPGA',
#    'alias': '21-shanghai-house-new-york-4',
#    'name': '21 Shanghai House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JTTk7-6DC-xGzthdKRK4CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/21-shanghai-house-new-york-4?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 415,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140138244835,
#     'longitude': -73.9964454932541},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Division St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 969.9399795414205}],
#  'total': 271,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
test = pd.DataFrame()
test.from_dict(restaurant_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-73bd833685ea> in <module>
#       1 test = pd.DataFrame()
# ----> 2 test.from_dict(restaurant_data)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1136             raise ValueError('only recognize index or columns for orient')
#    1137
# -> 1138         return cls(data, index=index, columns=columns, dtype=dtype)
#    1139
#    1140     def to_numpy(self, dtype=None, copy=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     318
#     319             if have_dicts:
# --> 320                 raise ValueError('Mixing dicts with non-Series may lead to '
#     321                                  'ambiguous ordering.')
#     322
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
for i in restaurant_data['businesses']:
    if 'price' not in i.keys():
        print ("NA")
# Out:
# NA
# NA
# NA
# NA
# NA

# %%
type(restaurant_data['businesses'][6]['price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-c8ef11012708> in <module>
# ----> 1 type(restaurant_data['businesses'][6]['price'])
#
# KeyError: 'price'

# %%
restaurantDF = pd.DataFrame()
count = 0


for i in restaurant_data['businesses']:
    temprestaurantDF = pd.DataFrame()
    temprestaurantDF.loc[count,'name'] = i['name']
    temprestaurantDF.loc[count,'categories'] = i['categories'][0]["alias"]
    temprestaurantDF.loc[count,'address'] = i['location']['address1']
    temprestaurantDF.loc[count,'price'] = i['price'] if 'price' in i.keys() else "NA"
    temprestaurantDF.loc[count,'latitude'] = i['coordinates']['latitude']
    temprestaurantDF.loc[count,'longitude'] = i['coordinates']['longitude']
    temprestaurantDF.loc[count,'rating'] = i['rating']
    temprestaurantDF.loc[count,'review_count'] = i['review_count']
    temprestaurantDF.loc[count,'display_phone'] = i['display_phone']
    restaurantDF = restaurantDF.append(pd.DataFrame(data = temprestaurantDF), ignore_index=True, sort=False)
    count = count + 1

restaurantDF
# Out:
#                                                  name       categories  \
# 0                                     Juliana's Pizza            pizza
# 1                               Fishmarket Restaurant          seafood
# 2                                        Atrium Dumbo      newamerican
# 3                            Time Out Market New York       food_court
# 4                           Tasty Hand-Pulled Noodles          chinese
# 5                                      Noodle Pudding          italian
# 6                     Jacob's Pickles Time Out Market      comfortfood
# 7                                      The River Café      newamerican
# 8                               Les Enfants de Boheme           french
# 9                               Jack the Horse Tavern      newamerican
# 10                                    Cecconi's Dumbo          italian
# 11                                          Celestine    mediterranean
# 12                                             Jajaja          mexican
# 13                                        Shanghai 21     shanghainese
# 14                Luke's Lobster Brooklyn Bridge Park          seafood
# 15                                     Noodle Village          chinese
# 16                                        IL Brigante          italian
# 17                            Sugarcane Raw Bar Grill            sushi
# 18                                           The Binc     cocktailbars
# 19                                 shabushabu Mayumon         japanese
# 20                                              AlMar          italian
# 21                                Grimaldi's Pizzeria            pizza
# 22                                            Wok Wok          chinese
# 23                                       Kogane Ramen            ramen
# 24                                         The Osprey      newamerican
# 25                                          Seamore's          seafood
# 26                                           Kopitiam        malaysian
# 27                                     The Paris Cafe       gastropubs
# 28                                   Sun Hing Lung Co          chinese
# 29                                            Hak Box          chinese
# 30                                    Westville Dumbo      newamerican
# 31                             Taiwan Pork Chop House        taiwanese
# 32                               Acqua Restaurant NYC          seafood
# 33                                           Suteishi         japanese
# 34                                         Fresh Salt             bars
# 35                                             Butler         bakeries
# 36                                   Cowgirl Seahorse          tex-mex
# 37                                 Barbalu Restaurant          italian
# 38                                          Superfine             bars
# 39                                         Taco Dumbo            latin
# 40                                        Henry's End      newamerican
# 41                                        Shake Shack     tradamerican
# 42                                             Wo Hop          chinese
# 43  The Original Buddha Bodai - Kosher Vegetarian ...          chinese
# 44                                     The Bao Shoppe      asianfusion
# 45                              MarkJoseph Steakhouse            steak
# 46                                         The Fulton          seafood
# 47                                  My Noodle Station          noodles
# 48                                      The Tuck Room  tapasmallplates
# 49                                  21 Shanghai House     shanghainese
#
#                    address price   latitude  longitude  rating  review_count  \
# 0         19 Old Fulton St    $$  40.702615 -73.993416     4.5        2051.0
# 1             111 South St    $$  40.707170 -74.001920     4.5         525.0
# 2               15 Main St    $$  40.703390 -73.990492     4.0         647.0
# 3              55 Water St    $$  40.703721 -73.991811     3.5         108.0
# 4              1 Doyers St     $  40.714200 -73.997870     4.0        1544.0
# 5              38 Henry St    $$  40.699790 -73.992030     4.0         550.0
# 6              55 Water St    NA  40.703620 -73.991650     4.5           9.0
# 7               1 Water St  $$$$  40.703180 -73.994650     4.0        1073.0
# 8             177 Henry St    $$  40.713619 -73.988850     4.5         213.0
# 9              66 Hicks St   $$$  40.699973 -73.993781     4.0         381.0
# 10             55 Water St   $$$  40.703306 -73.991655     3.5         562.0
# 11               1 John St   $$$  40.704676 -73.987975     4.0         192.0
# 12          162 E Broadway    $$  40.714153 -73.990425     4.5         755.0
# 13              21 Mott St    $$  40.714420 -73.998890     4.0        1571.0
# 14             11 Water St    $$  40.703590 -73.994110     4.0         299.0
# 15              13 Mott St     $  40.714167 -73.998803     4.0        1010.0
# 16            214 Front St    $$  40.707492 -74.002571     4.0         367.0
# 17             55 Water St   $$$  40.703799 -73.992343     4.0         491.0
# 18             60 Henry St    $$  40.699268 -73.992311     4.5          68.0
# 19         115 Division St    NA  40.714340 -73.992050     5.0           6.0
# 20            111 Front St    $$  40.702662 -73.989177     4.0         406.0
# 21              1 Front St    $$  40.702570 -73.993230     3.5        4541.0
# 22              11 Mott St    $$  40.714060 -73.998830     4.0         846.0
# 23             76 Henry St    $$  40.698608 -73.992675     4.0         303.0
# 24            60 Furman St    $$  40.702241 -73.995539     4.0         159.0
# 25             66 Water St    $$  40.703200 -73.991450     3.5          89.0
# 26          151 E Broadway     $  40.713870 -73.990910     4.0         519.0
# 27            119 South St    $$  40.707320 -74.001590     4.0         302.0
# 28             58 Henry St     $  40.712750 -73.995080     4.5         176.0
# 29           88 E Broadway    NA  40.713982 -73.994228     4.5          28.0
# 30        81 Washington St    $$  40.701797 -73.989632     4.0         242.0
# 31             3 Doyers St     $  40.714240 -73.997990     4.0         415.0
# 32  21 Peck Slip, Water St    $$  40.708257 -74.001797     4.0         355.0
# 33            24 Peck Slip   $$$  40.707880 -74.001940     4.0         468.0
# 34          146 Beekman St    $$  40.707070 -74.002440     4.0         386.0
# 35             40 Water St    NA  40.703267 -73.992242     4.5          63.0
# 36            259 Front St    $$  40.708136 -74.000453     4.0         557.0
# 37        225-227 Front St    $$  40.707475 -74.002040     4.0         268.0
# 38            126 Front St    $$  40.702236 -73.987426     3.5         441.0
# 39          56 Prospect St    $$  40.700601 -73.988467     4.0         161.0
# 40             72 Henry St   $$$  40.698689 -73.992560     4.0         344.0
# 41         1 Old Fulton St    $$  40.703015 -73.993954     4.0         331.0
# 42              17 Mott St    $$  40.714224 -73.998869     3.5        1359.0
# 43               5 Mott St    $$  40.713854 -73.998948     4.0         942.0
# 44             34 Canal St     $  40.714345 -73.990518     4.0         189.0
# 45            261 Water St  $$$$  40.708370 -74.001520     4.0         390.0
# 46             89 South St   $$$  40.705369 -74.001063     3.5          77.0
# 47          19 Eldridge St    NA  40.714047 -73.992304     4.5          37.0
# 48            11 Fulton St    $$  40.706540 -74.003250     3.5         243.0
# 49          21 Division St    $$  40.714014 -73.996445     4.0         415.0
#
#      display_phone
# 0   (718) 596-6700
# 1   (917) 363-8101
# 2   (718) 858-1095
# 3   (917) 810-4855
# 4   (212) 791-1817
# 5   (718) 625-3737
# 6
# 7   (718) 522-5200
# 8   (646) 476-4843
# 9   (718) 852-5084
# 10  (718) 650-3900
# 11  (718) 522-5356
# 12  (646) 883-5453
# 13  (212) 766-6311
# 14  (917) 882-7516
# 15  (212) 233-0788
# 16  (212) 285-0222
# 17  (718) 473-9555
# 18  (718) 624-1444
# 19  (646) 476-7717
# 20  (718) 855-5288
# 21  (718) 858-4300
# 22  (917) 388-3627
# 23  (718) 875-2828
# 24  (347) 696-2505
# 25  (718) 663-6550
# 26  (646) 609-3785
# 27  (212) 240-9797
# 28  (212) 962-7032
# 29
# 30  (718) 618-5699
# 31  (212) 791-7007
# 32  (212) 349-4433
# 33  (212) 766-2344
# 34  (212) 962-0053
# 35
# 36  (212) 608-7873
# 37  (646) 918-6565
# 38  (718) 243-9005
# 39  (347) 202-0306
# 40  (718) 834-1776
# 41  (347) 435-2676
# 42  (212) 962-8617
# 43  (212) 566-8388
# 44  (646) 756-4181
# 45  (212) 277-0020
# 46  (212) 838-1200
# 47
# 48  (212) 776-8273
# 49

# %%
#response
#restaurant_data = response.json()
#restaurant_data

# %%
#create json
#nyc_json = restaurantDF.to_json (orient = 'records')

# %%
#nyc_json

# %%
#Wrap array in dictionary
# nyc_json = {nyc_json:nyc_json}
# nyc_json

# %%
#Create a connection variable
conn = 'mongodb://localhost:27017'

# %%
#Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)

# %%
#Define database and collection
db = client.restaurant_db

# %%
#Drops collection if available to remoe duplicates
#db.restaurant_db.drop()

# %%
#Define ollection
collection = db.nyc_data

# %%
#Creates a collection in database and insert documents

# Insert documents
# collection.insert_many(nyc_json)
collection.insert_many(restaurantDF.to_dict('records'))
#db.restaurant_db.insert_many(nyc_json)
