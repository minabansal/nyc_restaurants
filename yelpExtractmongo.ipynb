# %%
import requests
import json
import pandas as pd
# Import API key
from yelp_keys import api_key
import pymongo

# %%
yelpAPI = 'https://api.yelp.com/v3/businesses/search'
header = {'Authorization':'bearer %s' % api_key}
parameters = {'term':'restaurants',
             'limit':50,
             'radius':10000,
             'categories' : 'All',
             'location': 'New York City',
             'is_closed': False}

# send a request
response = requests.get(url = yelpAPI, params = parameters, headers = header)

# %%
response
restaurant_data = response.json()
restaurant_data
# Out:
# {'businesses': [{'id': 'ehUuSk5gPTCQmwS_ubgKRA',
#    'alias': 'upstate-new-york-2',
#    'name': 'Upstate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU7MF7DT0RzNL-EebQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upstate-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1765,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7263139141197,
#     'longitude': -73.9864901976935},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '95 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 1st Ave', 'New York, NY 10003']},
#    'phone': '+16467915400',
#    'display_phone': '(646) 791-5400',
#    'distance': 2411.9187177986864},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 2534,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3038.8699032940094},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 4477,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7303859, 'longitude': -73.9860613},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2858.7729410008346},
#   {'id': 'CwOAKJdX8AMz5iAoA-ZEuA',
#    'alias': 'uglyduckling-brooklyn',
#    'name': 'Uglyduckling',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sCDU8uosDuxp26wjxq4p4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uglyduckling-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 456,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.686023, 'longitude': -73.991302},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '166 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17184513825',
#    'display_phone': '(718) 451-3825',
#    'distance': 2174.2838817065267},
#   {'id': 'I2lgw_7DUnwD92ND4PN-Ow',
#    'alias': 'aunt-jakes-new-york',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hMhn_lnES3QWc4Gtihvr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1312,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190315, 'longitude': -73.9977161},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '149 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 Mulberry St', 'New York, NY 10013']},
#    'phone': '+16468580470',
#    'display_phone': '(646) 858-0470',
#    'distance': 1538.0627375870665},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5TXMVrjARsqKQHDg-hKbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1174,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3155.0505772747442},
#   {'id': 'qm1J_dPA5IHij1oAnoZwHw',
#    'alias': 'nonono-new-york-6',
#    'name': 'nonono',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y3k4MtuStb4Yu4OTFbfmJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonono-new-york-6?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 454,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74545, 'longitude': -73.98499},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '118 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Madison Ave', 'New York, NY 10016']},
#    'phone': '+16467073227',
#    'display_phone': '(646) 707-3227',
#    'distance': 4515.897681612123},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxY50B6ntFYQa8COuI1Fog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 525,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 671.0784555500173},
#   {'id': 'xZ96vaoL-cQjfotmUKtjJQ',
#    'alias': 'barn-joo-35-new-york',
#    'name': 'Barn Joo 35',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1R5CgYlK5qGUhKZOvZThKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1645,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74964, 'longitude': -73.98582},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '34 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125644430',
#    'display_phone': '(212) 564-4430',
#    'distance': 4968.473297353009},
#   {'id': 'UA2M9QFZghe-9th2KwLoWQ',
#    'alias': 'burger-and-lobster-new-york-4',
#    'name': 'Burger & Lobster',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rHd7F4zztAsScwzM0vDmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york-4?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 5229,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '39 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 19th St', 'New York, NY 10011']},
#    'phone': '+16468337532',
#    'display_phone': '(646) 833-7532',
#    'distance': 3852.2188529432046},
#   {'id': 'm1cJLpDN4B-_0hGgPfe5OA',
#    'alias': 'salt-charcoal-brooklyn',
#    'name': 'Salt + Charcoal',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RDtbfJjYqtdpaKvTrRhh2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salt-charcoal-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 399,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71453, 'longitude': -73.9613511},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '171 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17187822087',
#    'display_phone': '(718) 782-2087',
#    'distance': 2954.688075109069},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'alias': 'thai-villa-new-york-2',
#    'name': 'Thai Villa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WiAKBRTVBgi92uG3z3o7cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 2783,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 E 19th St',
#     'address2': 'G Floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']},
#    'phone': '+12128029999',
#    'display_phone': '(212) 802-9999',
#    'distance': 3744.570399827637},
#   {'id': 'StF9WWWbrRzEOmNAcEINcA',
#    'alias': 'balzem-new-york',
#    'name': 'Balzem',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h3NWzD0mw_JJ8F03XowUaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balzem-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 408,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721408, 'longitude': -73.995415},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '202 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 Mott St', 'New York, NY 10012']},
#    'phone': '+16468377033',
#    'display_phone': '(646) 837-7033',
#    'distance': 1777.534042874945},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 2050,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 323.20506308227306},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'alias': 'joes-shanghai-new-york-2',
#    'name': "Joe's Shanghai",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 5886,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7146691442891,
#     'longitude': -73.9977602206654},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Pell St', 'New York, NY 10013']},
#    'phone': '+12122338888',
#    'display_phone': '(212) 233-8888',
#    'distance': 1066.5085498349097},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TAog5s7slOJ0778OGRzuWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 647,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 392.6441573431464},
#   {'id': 'nxTEuWKzkK1tCF4LrhFSUQ',
#    'alias': 'pig-and-khao-new-york',
#    'name': 'Pig and Khao',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bV_sHIsR3MFmclD63AmwKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pig-and-khao-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1516,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71926, 'longitude': -73.98475},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '68 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Clinton St', 'New York, NY 10002']},
#    'phone': '+12129204485',
#    'display_phone': '(212) 920-4485',
#    'distance': 1733.0778315167283},
#   {'id': 'cTE0e96GYzet799EJeStoQ',
#    'alias': 'chama-mama-new-york',
#    'name': 'Chama Mama',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qRZaBnsI-gfyaSTEIEGzgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chama-mama-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 134,
#    'categories': [{'alias': 'georgian', 'title': 'Georgian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7384, 'longitude': -73.99892},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '149 W 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 W 14th St', 'New York, NY 10011']},
#    'phone': '+16464389007',
#    'display_phone': '(646) 438-9007',
#    'distance': 3690.5460277554907},
#   {'id': 'XipQLDbyTl5tsLlyzAWzug',
#    'alias': 'jajaja-new-york',
#    'name': 'Jajaja',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QaIhCEp1FpU3a2teWQh6mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 755,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141530317142,
#     'longitude': -73.9904247969389},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '162 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E Broadway', 'New York, NY 10002']},
#    'phone': '+16468835453',
#    'display_phone': '(646) 883-5453',
#    'distance': 1021.7274074140097},
#   {'id': 'DoSU8IPq-Py_YV3kYmXPfQ',
#    'alias': 'trattoria-trecolori-new-york',
#    'name': 'Trattoria Trecolori',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/G8vBgHxbEfoONO0JpLX3Qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-trecolori-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 2197,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75998, 'longitude': -73.98671},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '254 West 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 West 47th St', 'New York, NY 10036']},
#    'phone': '+12129974540',
#    'display_phone': '(212) 997-4540',
#    'distance': 6083.735166572698},
#   {'id': 'rp8S7scxOkVVeG7dNneMGQ',
#    'alias': 'l-artusi-new-york',
#    'name': "L'Artusi",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1737,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733714, 'longitude': -74.005068},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '228 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 10th St', 'New York, NY 10014']},
#    'phone': '+12122555757',
#    'display_phone': '(212) 255-5757',
#    'distance': 3271.9116518313776},
#   {'id': '-udRA8VRsQJoIaT-kxCrGg',
#    'alias': 'ipanema-restaurant-new-york',
#    'name': 'Ipanema Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p7A065ZhtvsgsnVEaOfMuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ipanema-restaurant-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1282,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.757072217349,
#     'longitude': -73.9807795529175},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '43 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 W 46th St', 'New York, NY 10036']},
#    'phone': '+12127305848',
#    'display_phone': '(212) 730-5848',
#    'distance': 5852.5328132075565},
#   {'id': 'MphfKkYFEe0BDQ6hZ0A5fA',
#    'alias': 'gelso-and-grand-new-york',
#    'name': 'Gelso & Grand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HuHFQ0vaGnMsBu_5QcprXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gelso-and-grand-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 815,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7194089547259,
#     'longitude': -73.9973777877722},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '186 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Grand St', 'New York, NY 10013']},
#    'phone': '+12122261600',
#    'display_phone': '(212) 226-1600',
#    'distance': 1574.3490321455226},
#   {'id': 'OCTiJwvjoK81WoDwsTkFvA',
#    'alias': 'paesano-of-mulberry-street-new-york',
#    'name': 'Paesano of Mulberry Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yN9ARCE3LF6u9E0yN5WpIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paesano-of-mulberry-street-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 751,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718554, 'longitude': -73.997447},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '136 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12129651188',
#    'display_phone': '(212) 965-1188',
#    'distance': 1481.7066528289554},
#   {'id': 'qOomR3AwClOGpV1HdqOTFg',
#    'alias': 'les-enfants-de-boheme-new-york',
#    'name': 'Les Enfants de Boheme',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I1V4kucJO69x8L8UhDwiiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 213,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7136187, 'longitude': -73.9888503},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '177 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Henry St', 'New York, NY 10002']},
#    'phone': '+16464764843',
#    'display_phone': '(646) 476-4843',
#    'distance': 1026.2110364656392},
#   {'id': 'XEugUtbw4rRmGr9S1XA-aQ',
#    'alias': 'alta-new-york',
#    'name': 'Alta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aUWGUNBLw-mbQZOzJ9-Pdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alta-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1835,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7345163811398,
#     'longitude': -73.9983369619683},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '64 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 W 10th St', 'New York, NY 10011']},
#    'phone': '+12125057777',
#    'display_phone': '(212) 505-7777',
#    'distance': 3250.5152771255803},
#   {'id': '3xTQT7qjZJIxc-eBiFMerQ',
#    'alias': '1803-new-york',
#    'name': '1803',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cm0-hL9q0EC3nyYL4VhXGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1803-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 287,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715498, 'longitude': -74.007178},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '82 Reade St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Reade St', 'New York, NY 10007']},
#    'phone': '+12122673000',
#    'display_phone': '(212) 267-3000',
#    'distance': 1558.541688391669},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'alias': 'raku-new-york-7',
#    'name': 'Raku',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GEbZnH1jR4n7D5WOJ3urPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-new-york-7?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 936,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7264988089246,
#     'longitude': -73.9866526052356},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '342 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['342 E 6th St', 'New York, NY 10003']},
#    'phone': '+12122281324',
#    'display_phone': '(212) 228-1324',
#    'distance': 2428.0392489129867},
#   {'id': '0Tvwk0hvgaY0QVIsZGTZKQ',
#    'alias': 'antica-ristorante-new-york',
#    'name': 'Antica Ristorante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uORVHkBn9xrLR6yQYtl7Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antica-ristorante-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 474,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7039355145338,
#     'longitude': -74.0121731758117},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '8 Stone St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Stone St', 'New York, NY 10004']},
#    'phone': '+12124803880',
#    'display_phone': '(212) 480-3880',
#    'distance': 1516.5010643209548},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'alias': 'thursday-kitchen-new-york',
#    'name': 'Thursday Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mW2QK-sTLI7iSYHnA65tKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1225,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7275, 'longitude': -73.9838},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '424 E 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['424 E 9th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2613.42601480514},
#   {'id': '0dDCDQz7DrKkSvu9h2hcQw',
#    'alias': 'chow-house-new-york',
#    'name': 'Chow House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j8LfpqX_R6Rq9is4DVUABQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chow-house-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 305,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72915, 'longitude': -74.00072},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '181 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12128371021',
#    'display_phone': '(212) 837-1021',
#    'distance': 2692.4401801037266},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1995,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1931.2683716470422},
#   {'id': 'Hv5v8y3fvu6PjPiFf4jPVQ',
#    'alias': 'trading-post-new-york',
#    'name': 'Trading Post',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DD-8VVPSQzJOnE3P0fkUNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trading-post-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 395,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7059604, 'longitude': -74.0041871},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '170 John St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 John St', 'New York, NY 10038']},
#    'phone': '+16463703337',
#    'display_phone': '(646) 370-3337',
#    'distance': 835.9570087563299},
#   {'id': 'xt4sa64WOrpJvZBDPNPNYg',
#    'alias': 'jacobs-pickles-new-york',
#    'name': "Jacob's Pickles",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/167Rl2s1oMge_2ZSDD1z0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 3851,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7866504411994,
#     'longitude': -73.9755284786224},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '509 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12124705566',
#    'display_phone': '(212) 470-5566',
#    'distance': 9166.964737863183},
#   {'id': 'tiSw-6DIm3-mMORyEIOVyg',
#    'alias': 'the-boil-new-york-3',
#    'name': 'The Boil',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y8Zgcd9DTKb_MGfjSBbh3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boil-new-york-3?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1833,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71974, 'longitude': -73.99339},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '139 Chrystie St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129258815',
#    'display_phone': '(212) 925-8815',
#    'distance': 1594.3621278980172},
#   {'id': '04exhf1PZ79_Km9vHAzvfA',
#    'alias': 'pepe-rosso-social-new-york-2',
#    'name': 'Pepe Rosso Social',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MErF46rFrXUcnnfERnLDyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pepe-rosso-social-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 794,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72007, 'longitude': -73.99618},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '173 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['173 Mott St', 'New York, NY 10013']},
#    'phone': '+12122190019',
#    'display_phone': '(212) 219-0019',
#    'distance': 1632.387824313953},
#   {'id': 'Rc1lxc5lSKJYd162JHNMfQ',
#    'alias': 'bea-new-york',
#    'name': 'Bea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iVlolLTkpoSWA_VYtRR2ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bea-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 2343,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7591968, 'longitude': -73.9923361},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '403 W 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['403 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12126021910',
#    'display_phone': '(212) 602-1910',
#    'distance': 5979.210371091945},
#   {'id': '44SY464xDHbvOcjDzRbKkQ',
#    'alias': 'ippudo-ny-new-york-7',
#    'name': 'Ippudo NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zF3EgqHCk7zBUwD2B3WTEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ippudo-ny-new-york-7?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 9825,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73092, 'longitude': -73.99015},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '65 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 4th Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2854.3012674083675},
#   {'id': '22nKUyCIbpnzR6R3_g1ptQ',
#    'alias': 'carmines-italian-restaurant-times-square-new-york-5',
#    'name': "Carmine's Italian Restaurant - Times Square",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0UszeEYPWI-RIk0Ak6HtVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmines-italian-restaurant-times-square-new-york-5?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 3541,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7574955824307,
#     'longitude': -73.9866844540098},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 W 44th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 W 44th St', 'New York, NY 10036']},
#    'phone': '+12122213800',
#    'display_phone': '(212) 221-3800',
#    'distance': 5823.169973434953},
#   {'id': 'L7_siqDfU4-ZA17YtA-SBg',
#    'alias': 'silver-factory-brooklyn',
#    'name': 'Silver Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jTUCcGJiZZPLlEmx0EHgXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silver-factory-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 165,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.709227, 'longitude': -73.958598},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '270 South 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['270 South 5th St', 'Brooklyn, NY 11211']},
#    'phone': '+13477253017',
#    'display_phone': '(347) 725-3017',
#    'distance': 3039.9237511522865},
#   {'id': 'MGd6HFEq1ALD58XWNviSXw',
#    'alias': 'time-out-market-new-york-brooklyn',
#    'name': 'Time Out Market New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TmhwMz3q6IdmVVC8ZgZc8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/time-out-market-new-york-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 108,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7037211399782,
#     'longitude': -73.9918105285751},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19178104855',
#    'display_phone': '(917) 810-4855',
#    'distance': 283.7853104247956},
#   {'id': '4aF0F8w7yXX9o5_QFky_ig',
#    'alias': 'celestine-brooklyn',
#    'name': 'Celestine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J5HuHor_cmVEG6HhQtFeDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celestine-brooklyn?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 192,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704676, 'longitude': -73.987975},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 John St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225356',
#    'display_phone': '(718) 522-5356',
#    'distance': 539.4069533813018},
#   {'id': 'i6RhqnCJ_oUfTu5LikGXUg',
#    'alias': 'dun-huang-east-village-new-york-8',
#    'name': 'Dun Huang - East Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_aTrBIGDOF5GSDJpEGoF7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dun-huang-east-village-new-york-8?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 235,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73081, 'longitude': -73.98568},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '300 E 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 E 12th St', 'New York, NY 10003']},
#    'phone': '+12122543817',
#    'display_phone': '(212) 254-3817',
#    'distance': 2908.2544225724664},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'alias': 'raku-new-york-6',
#    'name': 'Raku',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dqDuhxEdkM4M3esKthJjLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-new-york-6?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 276,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72728, 'longitude': -74.00252},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '48 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129894797',
#    'display_phone': '(212) 989-4797',
#    'distance': 2522.2670460297},
#   {'id': 'ULt3kmA0_hbZ3j6cMORCaA',
#    'alias': 'root-and-bone-new-york',
#    'name': 'Root & Bone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WM96Qsx-7o11LNp1Lin9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/root-and-bone-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1532,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72272, 'longitude': -73.98334},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 E 3rd St', 'New York, NY 10009']},
#    'phone': '+16466827080',
#    'display_phone': '(646) 682-7080',
#    'distance': 2129.537859707603},
#   {'id': 'Pu09oBx1ekEZiFt90PsSIw',
#    'alias': 'tableside-italian-cook-shoppe-new-york',
#    'name': 'Tableside Italian Cook Shoppe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sCAL7j7Hrj3O1GG9gk6wDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tableside-italian-cook-shoppe-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 225,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266287, 'longitude': -73.9863384},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '345 E 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 E 6th St', 'New York, NY 10003']},
#    'phone': '+16468526498',
#    'display_phone': '(646) 852-6498',
#    'distance': 2449.276134809984},
#   {'id': 'XghOzJn16M-nvaKMOdC5og',
#    'alias': 'verlaine-new-york-2',
#    'name': 'Verlaine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nR7lloKPtdQD5afth8jQpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/verlaine-new-york-2?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1395,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720079, 'longitude': -73.987785},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '110 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Rivington St', 'New York, NY 10002']},
#    'phone': '+12126142494',
#    'display_phone': '(212) 614-2494',
#    'distance': 1717.209013709613},
#   {'id': 'VvsZAnEwU4c8Xkyrzx05Nw',
#    'alias': 'anytime-new-york',
#    'name': 'Anytime',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S-K4D44wXoqw-wTL4kX2cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 760,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74779, 'longitude': -73.98674},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '23 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16466697733',
#    'display_phone': '(646) 669-7733',
#    'distance': 4761.966725883583},
#   {'id': 'Vs8kQ4R381y27AH018gLpg',
#    'alias': 'supper-new-york',
#    'name': 'Supper',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jEEH9kmoHFmyQRgXiMjFuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supper-new-york?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1248,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7229, 'longitude': -73.98527},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12124777600',
#    'display_phone': '(212) 477-7600',
#    'distance': 2088.7434147525933},
#   {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#    'alias': 'bocaphê-new-york-3',
#    'name': 'BoCaphe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=fF5IyMDYKy157gyNvrDUrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fF5IyMDYKy157gyNvrDUrg',
#    'review_count': 1228,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722046, 'longitude': -73.997557},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '222 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16468821939',
#    'display_phone': '(646) 882-1939',
#    'distance': 1866.3436634084576}],
#  'total': 16100,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
restaurantDF = pd.DataFrame()
count = 0
for i in restaurant_data['businesses']:
    temprestaurantDF = pd.DataFrame()
    temprestaurantDF.loc[count,'name'] = i['name']
    temprestaurantDF.loc[count,'address'] = i['location']['address1']
    temprestaurantDF.loc[count,'latitude'] = i['coordinates']['latitude']
    temprestaurantDF.loc[count,'longitude'] = i['coordinates']['longitude']
    temprestaurantDF.loc[count,'rating'] = i['rating']
    temprestaurantDF.loc[count,'review_count'] = i['review_count']
    temprestaurantDF.loc[count,'price'] = i['price']
    temprestaurantDF.loc[count,'display_phone'] = i['display_phone']
    restaurantDF = restaurantDF.append(pd.DataFrame(data = temprestaurantDF), ignore_index=True, sort=False)
    count = count + 1

restaurantDF
# Out:
#                                            name            address   latitude  \
# 0                                       Upstate         95 1st Ave  40.726314
# 1                                        Amélie        22 W 8th St  40.732700
# 2                                      LoveMama        174 2nd Ave  40.730386
# 3                                  Uglyduckling       166 Smith St  40.686023
# 4                                   Aunt Jake's    149 Mulberry St  40.719031
# 5                        Boucherie West Village       99 7th Ave S  40.733063
# 6                                        nonono    118 Madison Ave  40.745450
# 7                         Fishmarket Restaurant       111 South St  40.707170
# 8                                   Barn Joo 35       34 W 35th St  40.749640
# 9                              Burger & Lobster       39 W 19th St  40.740070
# 10                              Salt + Charcoal       171 Grand St  40.714530
# 11                                   Thai Villa        5 E 19th St  40.739020
# 12                                       Balzem        202 Mott St  40.721408
# 13                              Juliana's Pizza   19 Old Fulton St  40.702615
# 14                               Joe's Shanghai          9 Pell St  40.714669
# 15                                 Atrium Dumbo         15 Main St  40.703390
# 16                                 Pig and Khao      68 Clinton St  40.719260
# 17                                   Chama Mama      149 W 14th St  40.738400
# 18                                       Jajaja     162 E Broadway  40.714153
# 19                          Trattoria Trecolori   254 West 47th St  40.759980
# 20                                     L'Artusi      228 W 10th St  40.733714
# 21                           Ipanema Restaurant       43 W 46th St  40.757072
# 22                                Gelso & Grand       186 Grand St  40.719409
# 23                   Paesano of Mulberry Street    136 Mulberry St  40.718554
# 24                        Les Enfants de Boheme       177 Henry St  40.713619
# 25                                         Alta       64 W 10th St  40.734516
# 26                                         1803        82 Reade St  40.715498
# 27                                         Raku       342 E 6th St  40.726499
# 28                            Antica Ristorante         8 Stone St  40.703936
# 29                             Thursday Kitchen       424 E 9th St  40.727500
# 30                                   Chow House    181 Bleecker St  40.729150
# 31                                     Rubirosa    235 Mulberry St  40.722750
# 32                                 Trading Post        170 John St  40.705960
# 33                              Jacob's Pickles  509 Amsterdam Ave  40.786650
# 34                                     The Boil    139 Chrystie St  40.719740
# 35                            Pepe Rosso Social        173 Mott St  40.720070
# 36                                          Bea      403 W 43rd St  40.759197
# 37                                    Ippudo NY         65 4th Ave  40.730920
# 38  Carmine's Italian Restaurant - Times Square      200 W 44th St  40.757496
# 39                               Silver Factory   270 South 5th St  40.709227
# 40                     Time Out Market New York        55 Water St  40.703721
# 41                                    Celestine          1 John St  40.704676
# 42                     Dun Huang - East Village      300 E 12th St  40.730810
# 43                                         Raku    48 Macdougal St  40.727280
# 44                                  Root & Bone       200 E 3rd St  40.722720
# 45                Tableside Italian Cook Shoppe       345 E 6th St  40.726629
# 46                                     Verlaine   110 Rivington St  40.720079
# 47                                      Anytime       23 W 32nd St  40.747790
# 48                                       Supper       156 E 2nd St  40.722900
# 49                                      BoCaphe   222 Lafayette St  40.722046
#
#     longitude  rating  review_count price   display_phone
# 0  -73.986490     4.5        1765.0    $$  (646) 791-5400
# 1  -73.997660     4.5        2534.0    $$  (212) 533-2962
# 2  -73.986061     4.5        4477.0    $$  (212) 254-5370
# 3  -73.991302     4.0         456.0    $$  (718) 451-3825
# 4  -73.997716     4.0        1312.0    $$  (646) 858-0470
# 5  -74.002877     4.5        1174.0   $$$  (212) 837-1616
# 6  -73.984990     4.5         454.0    $$  (646) 707-3227
# 7  -74.001920     4.5         525.0    $$  (917) 363-8101
# 8  -73.985820     4.5        1645.0    $$  (212) 564-4430
# 9  -73.993440     4.0        5229.0    $$  (646) 833-7532
# 10 -73.961351     4.0         399.0    $$  (718) 782-2087
# 11 -73.990650     4.5        2783.0    $$  (212) 802-9999
# 12 -73.995415     4.0         408.0    $$  (646) 837-7033
# 13 -73.993416     4.5        2050.0    $$  (718) 596-6700
# 14 -73.997760     4.0        5886.0    $$  (212) 233-8888
# 15 -73.990492     4.0         647.0    $$  (718) 858-1095
# 16 -73.984750     4.0        1516.0    $$  (212) 920-4485
# 17 -73.998920     4.5         134.0    $$  (646) 438-9007
# 18 -73.990425     4.5         755.0    $$  (646) 883-5453
# 19 -73.986710     4.0        2197.0    $$  (212) 997-4540
# 20 -74.005068     4.5        1737.0   $$$  (212) 255-5757
# 21 -73.980780     4.0        1282.0    $$  (212) 730-5848
# 22 -73.997378     4.5         815.0    $$  (212) 226-1600
# 23 -73.997447     4.0         751.0    $$  (212) 965-1188
# 24 -73.988850     4.5         213.0    $$  (646) 476-4843
# 25 -73.998337     4.0        1835.0   $$$  (212) 505-7777
# 26 -74.007178     4.5         287.0    $$  (212) 267-3000
# 27 -73.986653     4.5         936.0    $$  (212) 228-1324
# 28 -74.012173     4.5         474.0   $$$  (212) 480-3880
# 29 -73.983800     4.5        1225.0    $$
# 30 -74.000720     4.5         305.0    $$  (212) 837-1021
# 31 -73.996220     4.5        1995.0    $$  (212) 965-0500
# 32 -74.004187     4.0         395.0    $$  (646) 370-3337
# 33 -73.975528     4.0        3851.0    $$  (212) 470-5566
# 34 -73.993390     4.5        1833.0    $$  (212) 925-8815
# 35 -73.996180     4.0         794.0    $$  (212) 219-0019
# 36 -73.992336     4.0        2343.0    $$  (212) 602-1910
# 37 -73.990150     4.0        9825.0    $$
# 38 -73.986684     4.0        3541.0    $$  (212) 221-3800
# 39 -73.958598     4.5         165.0    $$  (347) 725-3017
# 40 -73.991811     3.5         108.0    $$  (917) 810-4855
# 41 -73.987975     4.0         192.0   $$$  (718) 522-5356
# 42 -73.985680     4.5         235.0    $$  (212) 254-3817
# 43 -74.002520     4.5         276.0    $$  (212) 989-4797
# 44 -73.983340     4.0        1532.0    $$  (646) 682-7080
# 45 -73.986338     4.5         225.0    $$  (646) 852-6498
# 46 -73.987785     4.0        1395.0    $$  (212) 614-2494
# 47 -73.986740     5.0         760.0    $$  (646) 669-7733
# 48 -73.985270     4.0        1248.0    $$  (212) 477-7600
# 49 -73.997557     4.0        1228.0    $$  (646) 882-1939

# %%
#response
#restaurant_data = response.json()
#restaurant_data

# %%
#create json
# nyc_json = restaurantDF.to_json (orient = 'records')

# %%
nyc_json
# Out:
# {'[{"name":"Upstate","address":"95 1st Ave","latitude":40.7263139141,"longitude":-73.9864901977,"rating":4.5,"review_count":1765.0,"price":"$$","display_phone":"(646) 791-5400"},{"name":"Am\\u00e9lie","address":"22 W 8th St","latitude":40.7327,"longitude":-73.99766,"rating":4.5,"review_count":2534.0,"price":"$$","display_phone":"(212) 533-2962"},{"name":"LoveMama","address":"174 2nd Ave","latitude":40.7303859,"longitude":-73.9860613,"rating":4.5,"review_count":4477.0,"price":"$$","display_phone":"(212) 254-5370"},{"name":"Uglyduckling","address":"166 Smith St","latitude":40.686023,"longitude":-73.991302,"rating":4.0,"review_count":456.0,"price":"$$","display_phone":"(718) 451-3825"},{"name":"Aunt Jake\'s","address":"149 Mulberry St","latitude":40.7190315,"longitude":-73.9977161,"rating":4.0,"review_count":1312.0,"price":"$$","display_phone":"(646) 858-0470"},{"name":"Boucherie West Village","address":"99 7th Ave S","latitude":40.733063,"longitude":-74.0028772,"rating":4.5,"review_count":1174.0,"price":"$$$","display_phone":"(212) 837-1616"},{"name":"nonono","address":"118 Madison Ave","latitude":40.74545,"longitude":-73.98499,"rating":4.5,"review_count":454.0,"price":"$$","display_phone":"(646) 707-3227"},{"name":"Fishmarket Restaurant","address":"111 South St","latitude":40.70717,"longitude":-74.00192,"rating":4.5,"review_count":525.0,"price":"$$","display_phone":"(917) 363-8101"},{"name":"Barn Joo 35","address":"34 W 35th St","latitude":40.74964,"longitude":-73.98582,"rating":4.5,"review_count":1645.0,"price":"$$","display_phone":"(212) 564-4430"},{"name":"Burger & Lobster","address":"39 W 19th St","latitude":40.74007,"longitude":-73.99344,"rating":4.0,"review_count":5229.0,"price":"$$","display_phone":"(646) 833-7532"},{"name":"Salt + Charcoal","address":"171 Grand St","latitude":40.71453,"longitude":-73.9613511,"rating":4.0,"review_count":399.0,"price":"$$","display_phone":"(718) 782-2087"},{"name":"Thai Villa","address":"5 E 19th St","latitude":40.73902,"longitude":-73.99065,"rating":4.5,"review_count":2783.0,"price":"$$","display_phone":"(212) 802-9999"},{"name":"Balzem","address":"202 Mott St","latitude":40.721408,"longitude":-73.995415,"rating":4.0,"review_count":408.0,"price":"$$","display_phone":"(646) 837-7033"},{"name":"Juliana\'s Pizza","address":"19 Old Fulton St","latitude":40.702615303,"longitude":-73.9934159994,"rating":4.5,"review_count":2050.0,"price":"$$","display_phone":"(718) 596-6700"},{"name":"Joe\'s Shanghai","address":"9 Pell St","latitude":40.7146691443,"longitude":-73.9977602207,"rating":4.0,"review_count":5886.0,"price":"$$","display_phone":"(212) 233-8888"},{"name":"Atrium Dumbo","address":"15 Main St","latitude":40.7033899,"longitude":-73.9904923,"rating":4.0,"review_count":647.0,"price":"$$","display_phone":"(718) 858-1095"},{"name":"Pig and Khao","address":"68 Clinton St","latitude":40.71926,"longitude":-73.98475,"rating":4.0,"review_count":1516.0,"price":"$$","display_phone":"(212) 920-4485"},{"name":"Chama Mama","address":"149 W 14th St","latitude":40.7384,"longitude":-73.99892,"rating":4.5,"review_count":134.0,"price":"$$","display_phone":"(646) 438-9007"},{"name":"Jajaja","address":"162 E Broadway","latitude":40.7141530317,"longitude":-73.9904247969,"rating":4.5,"review_count":755.0,"price":"$$","display_phone":"(646) 883-5453"},{"name":"Trattoria Trecolori","address":"254 West 47th St","latitude":40.75998,"longitude":-73.98671,"rating":4.0,"review_count":2197.0,"price":"$$","display_phone":"(212) 997-4540"},{"name":"L\'Artusi","address":"228 W 10th St","latitude":40.733714,"longitude":-74.005068,"rating":4.5,"review_count":1737.0,"price":"$$$","display_phone":"(212) 255-5757"},{"name":"Ipanema Restaurant","address":"43 W 46th St","latitude":40.7570722173,"longitude":-73.9807795529,"rating":4.0,"review_count":1282.0,"price":"$$","display_phone":"(212) 730-5848"},{"name":"Gelso & Grand","address":"186 Grand St","latitude":40.7194089547,"longitude":-73.9973777878,"rating":4.5,"review_count":8 ...

# %%
#Wrap array in dictionary
# nyc_json = {nyc_json:nyc_json}
# nyc_json

# %%
#Create a connection variable
conn = 'mongodb://localhost:27017'

# %%
#Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)

# %%
#Define database and collection
db = client.restaurant_db

# %%
#Drops collection if available to remoe duplicates
#db.restaurant_db.drop()

# %%
#Define ollection
collection = db.nyc_data

# %%
#Creates a collection in database and insert documents

# Insert documents
# collection.insert_many(nyc_json)
collection.insert_many(restaurantDF.to_dict('records'))
#db.restaurant_db.insert_many(nyc_json)
